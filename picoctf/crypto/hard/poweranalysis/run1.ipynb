# %%
import pandas as pd
import numpy as np
from scipy import stats
# nc saturn.picoctf.net 61727
# if odd -> leak a bit
# The power consumption is correlated with the Hamming weight of the bits being processed
# Hamming Weight -> distance of resulting ciphertext from 111111111111111
LEN = 2666

# %%
file = 0
temp = [int(i) for i in open("traces1/traces"+str(file)+".txt", "r").readlines()]
df = pd.DataFrame(temp, columns=["power"])
df.rolling(window=128).mean().plot()
# Out:
# <Axes: >

# %%
pd.DataFrame(temp, columns=["power"]).rolling(window=100).mean().iloc[300:].plot()
# Out:
# <Axes: >

# %%
pd.DataFrame(temp, columns=["power"]).rolling(window=100).mean().iloc[300:].plot()
# Out:
# <Axes: >

# %%
pd.DataFrame(temp, columns=["power"]).rolling(window=100).mean().iloc[300:].plot()
# Out:
# <Axes: >

# %%
df.reset_index().plot(kind="scatter", x='index', y='power')
# Out:
# <Axes: xlabel='index', ylabel='power'>
