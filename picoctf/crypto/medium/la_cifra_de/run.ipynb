# %% [markdown]
# https://www.dcode.fr/vigenere-cipher \
# Key is flag rotated, agfl decrypts the relevant segment \
# picoCTF{b311a50_0r_v1gn3r3_c1ph3r7b996649}

# %%
k = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
K = "====J=M=I====Y===R===G===="
# sxzqZNV
# 0123456789
# OIREASGTB 
# picoCTF{L6Y4G_4L41H515_15_73B10W5_8F1KF808
#         NGRAM
# picoCTF{L6YAG_ANALYSIS_IS_TEDIOUS_)}
mapping = dict(zip(K, k))

# %%
enc = """Ne iy nytkwpsznyg nth it mtsztcy vjzprj zfzjy rkhpibj nrkitt ltc tnnygy ysee itd tte cxjltk
                                  Vigenere
Ifrosr tnj noawde uk siyyzre, yse Bnretèwp Cousex mls hjpn xjtnbjytki xatd eisjd
                                       Vigenere
Iz bls lfwskqj azycihzeej yz Brftsk ip Volpnèxj ls oy hay tcimnyarqj dkxnrogpd os 1553 my Mnzvgs Mazytszf Merqlsu ny hox moup Wa inqrg ipl. Ynr. Gotgat Gltzndtg Gplrfdo 

Ltc tnj tmvqpmkseaznzn uk ehox nivmpr g ylbrj ts ltcmki my yqtdosr tnj wocjc hgqq ol fy oxitngwj arusahje fuw ln guaaxjytrd catizm tzxbkw zf vqlckx hizm ceyupcz yz tnj fpvjc hgqqpohzCZK{m311a50_0x_a1rn3x3_h1ah3x7g996649}

Ehk ktryy herq-ooizxetypd jjdcxnatoty ol f aordllvmlbkytc inahkw socjgex, bls sfoe gwzuti 1467 my Rjzn Hfetoxea Gqmexyt.
    Vigenere
Tnj Gimjyèrk Htpnjc iy ysexjqoxj dosjeisjd cgqwej yse Gqmexyt Doxn ox Fwbkwei Inahkw.

Tn 1508, Ptsatsps Zwttnjxiax tnbjytki ehk xz-cgqwej ylbaql rkhea (g rltxni ol xsilypd gqahggpty) ysaz bzuri wazjc bk f nroytcgq nosuznkse ol yse Bnretèwp Cousex.

Gplrfdo'y xpcuso butvlky lpvjlrki tn 1555 gx l cuseitzltoty ol yse lncsz. Yse rthex mllbjd ol yse gqahggpty fce tth snnqtki cemzwaxqj, bay ehk fwpnfmezx lnj yse osoed qptzjcs gwp mocpd hd xegsd ol f xnkrznoh vee usrgxp, wnnnh ify bk itfljcety hizm paim noxwpsvtydkse.
"""
out = ""
for i in range(len(enc)):
    if (enc[i].upper() in mapping.keys()):
        tmp = mapping[enc[i].upper()]
        out+= tmp.lower() if enc[i].islower() else tmp
    else:
        out+=enc[i]
print(out)
# Out:
# Ne iy nytfwpstnyg nth it mtsttcy vjtprj tftjy rfhpibj nrfitt ltc tnnygy ysee itd tte cxjltf
#
# Ifrosr tnj noawde uf siyytre, yse Bnretèwp Cousex mls hjpn xjtnbjytfi xatd eisjd
#
# It bls lfwsfqj atycihteej yt Brftsf ip Volpnèxj ls oy hay tcimnyarqj dfxnrogpd os 1553 my Mntvgs Matytstf Merqlsu ny hox moup Wa inqrg ipl. Ynr. Gotgat Glttndtg Gplrfdo
#
# Ltc tnj tmvqpmfseatntn uf ehox nivmpr g ylbrj ts ltcmfi my yqtdosr tnj wocjc hgqq ol fy oxitngwj arusahje fuw ln guaaxjytrd catitm ttxbfw tf vqlcfx hitm ceyupct yt tnj fpvjc hgqqpohtCTF{m311a50_0x_a1rn3x3_h1ah3x7g996649}
#
# Ehf ftryy herq-ooitxetypd jjdcxnatoty ol f aordllvmlbfytc inahfw socjgex, bls sfoe gwtuti 1467 my Rjtn Hfetoxea Gqmexyt.
#     Vigenère
# Tnj Gimjyèrf Htpnjc iy ysexjqoxj dosjeisjd cgqwej yse Gqmexyt Doxn ox Fwbfwei Inahfw.
#
# Tn 1508, Ptsatsps Twttnjxiax tnbjytfi ehf xt-cgqwej ylbaql rfhea (g rltxni ol xsilypd gqahggpty) ysat bturi watjc bf f nroytcgq nosutnfse ol yse Bnretèwp Cousex.
#
# ...

# %%
for i in range(26): 
    for j in range(26): print(chr(65+i)+"ELL"+chr(65+j)+"SO")
# Out:
# AELLASO
# AELLBSO
# AELLCSO
# AELLDSO
# AELLESO
# AELLFSO
# AELLGSO
# AELLHSO
# AELLISO
# AELLJSO
# AELLKSO
# AELLLSO
# AELLMSO
# AELLNSO
# AELLOSO
# AELLPSO
# AELLQSO
# AELLRSO
# AELLSSO
# AELLTSO
# AELLUSO
# AELLVSO
# AELLWSO
# AELLXSO
# AELLYSO
# AELLZSO
# BELLASO
# BELLBSO
# BELLCSO
# BELLDSO
# BELLESO
# BELLFSO
# BELLGSO
# BELLHSO
# BELLISO
# BELLJSO
# BELLKSO
# BELLLSO
# BELLMSO
# BELLNSO
# BELLOSO
# BELLPSO
# BELLQSO
# BELLRSO
# BELLSSO
# BELLTSO
# BELLUSO
# BELLVSO
# BELLWSO
# BELLXSO
# BELLYSO
# BELLZSO
# CELLASO
# CELLBSO
# CELLCSO
# CELLDSO
# CELLESO
# CELLFSO
# CELLGSO
# CELLHSO
# CELLISO
# CELLJSO
# CELLKSO
# CELLLSO
# CELLMSO
# CELLNSO
# CELLOSO
# CELLPSO
# CELLQSO
# CELLRSO
# CELLSSO
# CELLTSO
# CELLUSO
# CELLVSO
# CELLWSO
# CELLXSO
# CELLYSO
# CELLZSO
# DELLASO
# DELLBSO
# DELLCSO
# DELLDSO
# DELLESO
# DELLFSO
# DELLGSO
# DELLHSO
# DELLISO
# DELLJSO
# DELLKSO
# DELLLSO
# DELLMSO
# DELLNSO
# DELLOSO
# DELLPSO
# DELLQSO
# DELLRSO
# DELLSSO
# DELLTSO
# DELLUSO
# DELLVSO
# ...

# %%
aeiou

# %%
# _ELL_SO OF _L__EFE
