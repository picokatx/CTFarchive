# %%
from cryptolib import crt, gcd, hastad, mod_inv
from sympy import integer_nthroot
from Crypto.Util.number import long_to_bytes

# %%
n = [
    ...,
    ...,
    ...,
    ...,
    ...,
    ...,
    ...
]
c = [
    ... ,
    ... ,
    ... ,
    ... ,
    ... ,
    ...,
    ...
]
e = 3
long_to_bytes(hastad(c,n,e))
# Out:
# b'yes\n\n---\n\nJohan Hastad\nProfessor in Computer Science in the Theoretical Computer Science\nGroup at the School of Computer Science and Communication at KTH Royal Institute of Technology in Stockholm, Sweden.\n\ncrypto{1f_y0u_d0nt_p4d_y0u_4r3_Vuln3rabl3}'

# %%
integer_nthroot(crt([c[0], c[2], c[5]], [n[0], n[2], n[5]]), e)
# Out:
# (...,
#  True)

# %%
from Crypto.Util import number
from itertools import combinations
for grp in combinations(zip(n, c), e):
    N = 1
    for x in grp: N *= x[0]

    M = 0
    for x in grp:
        M += x[1]*number.inverse(N//x[0], x[0])*(N//x[0])
    M %= N

    m, exact = integer_nthroot(M, e)
    if exact:
        print(M)
# Out:
# ...

# %%
(
    (..., 
    ...), 
    (..., 
    ...), 

    (..., 
    ...)
) 

...

# %%
import sys
sys.set_int_max_str_digits(10000)
integer_nthroot(crt(c, n), e)
# Out:
# (...,
#  False)

# %%
x=... (mod ...)
x=... (mod ...)
x=... (mod ...)
x=... (mod ...)
x=... (mod ...)
x=... (mod ...)
x=... (mod ...)

# %%
c1 = pow(102, 2, 377)**2
c2 = pow(102, 2, 391)**2
c3 = pow(102, 2, 589)**2
c4 = pow(102, 2, 37)**2
# [c1**2 % 377, c2**2 % 391, c3**2 % 589]
integer_nthroot(crt([c1, c2, c3, c4], [377, 391, 589, 37]), 4)
# Out:
# (102, True)

# %%
crt([c1, c2, c3, c4], [377, 391, 589, 37])
# Out:
# 108243216

# %%
crt_out = crt(c, [n[0], n[1], n[2]])
# Out:
# ...

# %%
pow(102, 3, 377)**2 % 377
# Out:
# 324

# %%
pow(102, 6, 377)
# Out:
# 324
