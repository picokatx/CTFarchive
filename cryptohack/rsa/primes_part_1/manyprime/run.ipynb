# %%
from Crypto.Util.number import inverse, long_to_bytes
from sympy import root, lcm
from sympy.ntheory.ecm import ecm
from math import prod

# %%
n = ...
e = 65537
ct = ...

# %%
ecm(n)
# Out:
# {mpz(9282105380008121879),
#  mpz(9303850685953812323),
#  mpz(9389357739583927789),
#  mpz(10336650220878499841),
#  mpz(10638241655447339831),
#  mpz(11282698189561966721),
#  mpz(11328768673634243077),
#  mpz(11403460639036243901),
#  mpz(11473665579512371723),
#  mpz(11492065299277279799),
#  mpz(11530534813954192171),
#  mpz(11665347949879312361),
#  mpz(12132158321859677597),
#  mpz(12834461276877415051),
#  mpz(12955403765595949597),
#  mpz(12973972336777979701),
#  mpz(13099895578757581201),
#  mpz(13572286589428162097),
#  mpz(14100640260554622013),
#  mpz(14178869592193599187),
#  mpz(14278240802299816541),
#  mpz(14523070016044624039),
#  mpz(14963354250199553339),
#  mpz(15364597561881860737),
#  mpz(15669758663523555763),
#  mpz(15824122791679574573),
#  mpz(15998365463074268941),
#  mpz(16656402470578844539),
#  mpz(16898740504023346457),
#  mpz(17138336856793050757),
#  mpz(17174065872156629921),
#  mpz(17281246625998849649)}

# %%
factors = [
    9282105380008121879,
    9303850685953812323,
    9389357739583927789,
    10336650220878499841,
    10638241655447339831,
    11282698189561966721,
    11328768673634243077,
    11403460639036243901,
    11473665579512371723,
    11492065299277279799,
    11530534813954192171,
    11665347949879312361,
    12132158321859677597,
    12834461276877415051,
    12955403765595949597,
    12973972336777979701,
    13099895578757581201,
    13572286589428162097,
    14100640260554622013,
    14178869592193599187,
    14278240802299816541,
    14523070016044624039,
    14963354250199553339,
    15364597561881860737,
    15669758663523555763,
    15824122791679574573,
    15998365463074268941,
    16656402470578844539,
    16898740504023346457,
    17138336856793050757,
    17174065872156629921,
    17281246625998849649
]
tn = prod([f-1 for f in factors])
d = inverse(e, tn)
long_to_bytes(pow(ct, d, n))
# Out:
# b'crypto{700_m4ny_5m4ll_f4c70r5}'
