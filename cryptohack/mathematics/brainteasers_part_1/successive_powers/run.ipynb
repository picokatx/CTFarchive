# %%
from sympy import isprime
powers = [588, 665, 216, 113, 642, 4, 836, 114, 851, 492, 819, 237]
basis = [x for x in range(853,1000) if isprime(x)]
for p in basis:
    for x in range(1,p):
        for i,power in enumerate(powers):
            if i==len(powers)-1:
                print('crypto{',p,',',x,'}',sep='')
            elif not (x*power)%p==powers[i+1]: break
# Out:
# crypto{919,209}

# %%
temp = 851
for i in range(temp, 999):
    588+

# %%
pow(3,256, 256)
# Out:
# 1

# %%
[(9**i -1) % 620 for i in range(851,999)].index(0)
# Out:
# 19

# %%
9**870 // 620
# Out:
# ...

# %%
[pow(9, i, 870) for i in range(1,100)]
# Out:
# [9,
#  81,
#  729,
#  471,
#  759,
#  741,
#  579,
#  861,
#  789,
#  141,
#  399,
#  111,
#  129,
#  291,
#  9,
#  81,
#  729,
#  471,
#  759,
#  741,
#  579,
#  861,
#  789,
#  141,
#  399,
#  111,
#  129,
#  291,
#  9,
#  81,
#  729,
#  471,
#  759,
#  741,
#  579,
#  861,
#  789,
#  141,
#  399,
#  111,
#  129,
#  291,
#  9,
#  81,
#  729,
#  471,
#  759,
#  741,
#  579,
#  861,
#  789,
#  141,
#  399,
#  111,
#  129,
#  291,
#  9,
#  81,
#  729,
#  471,
#  759,
#  741,
#  579,
#  861,
#  789,
#  141,
#  399,
#  111,
#  129,
#  291,
#  9,
#  81,
#  729,
#  471,
#  759,
#  741,
#  579,
#  861,
#  789,
#  141,
#  399,
#  111,
#  129,
#  291,
#  9,
#  81,
#  729,
#  471,
#  759,
#  741,
#  579,
#  861,
#  789,
#  141,
#  399,
#  111,
#  129,
#  291,
#  9]

# %%
x = ...

# %%
743-216
# Out:
# 527

# %%
[(588**2 - 216)% i for i in range(852, 999)]
# Out:
# [468,
#  63,
#  512,
#  108,
#  560,
#  157,
#  612,
#  210,
#  668,
#  267,
#  728,
#  328,
#  792,
#  393,
#  860,
#  462,
#  64,
#  535,
#  138,
#  612,
#  216,
#  693,
#  298,
#  778,
#  384,
#  867,
#  474,
#  81,
#  568,
#  176,
#  666,
#  275,
#  768,
#  378,
#  874,
#  485,
#  96,
#  596,
#  208,
#  711,
#  324,
#  830,
#  444,
#  58,
#  568,
#  183,
#  696,
#  312,
#  828,
#  445,
#  62,
#  582,
#  200,
#  723,
#  342,
#  868,
#  488,
#  108,
#  638,
#  259,
#  792,
#  414,
#  36,
#  573,
#  196,
#  736,
#  360,
#  903,
#  528,
#  153,
#  700,
#  326,
#  876,
#  503,
#  130,
#  684,
#  312,
#  869,
#  498,
#  127,
#  688,
#  318,
#  882,
#  513,
#  144,
#  712,
#  344,
#  915,
#  548,
#  181,
#  756,
#  390,
#  24,
#  603,
#  238,
#  820,
#  456,
#  92,
#  678,
#  315,
#  904,
#  542,
#  180,
#  773,
#  412,
#  51,
#  648,
#  288,
#  888,
#  529,
#  170,
#  774,
#  416,
#  58,
#  666,
#  309,
#  920,
#  564,
#  208,
#  823,
#  468,
#  113,
#  732,
#  378,
#  24,
#  647,
# ...

# %%
pow(3,65536, 65536)
# Out:
# 1
