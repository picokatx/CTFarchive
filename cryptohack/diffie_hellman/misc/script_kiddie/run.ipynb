# %%
p = ...
g = 2
A = ...
B = ...
iv = 'c044059ae57b61821a9090fbdefc63c5'
encrypted_flag = 'f60522a95bde87a9ff00dc2c3d99177019f625f3364188c1058183004506bf96541cf241dad1c0e92535564e537322d7'

# %%
a = A ^ 2
b = B ^ 2
secret = ((g ^ a) ^ b) % p
from script_70449139467b5442a859d310e6945690 import decrypt_flag
decrypt_flag(secret, iv, encrypted_flag)
# b<(p-1)//2
# Out:
# 'crypto{b3_c4r3ful_w1th_y0ur_n0tati0n}'

# %%
10 ^ 2
# Out:
# 8

# %%
from Crypto.Util.number import inverse
inverse(g, p)
# Out:
# ...

# %%
(p-1)//2
# Out:
# ...

# %%
# A = g+a mod p
# B = g+b mod p, 2<b<(p-1)/2
