# %%
from pwnlib.tubes.remote import remote
from cryptolib import hello_world, get_key
from sympy import root
from Crypto.Util.number import bytes_to_long, long_to_bytes
r = hello_world()
key1 = get_key(r)
key2 = get_key(r)
key3 = get_key(r)
key4 = get_key(r)
key5 = get_key(r)

# %%
from pwnlib.tubes.remote import remote
from cryptolib import hello_world, get_key, gcd
from sympy import root
from Crypto.Util.number import bytes_to_long, long_to_bytes
from sympy.core.numbers import Integer
from math import prod
keys = [{'time_capsule': '',
 'pubkey': ['',
  '5']},{'time_capsule': '',
 'pubkey': ['',
  '5']},{'time_capsule': '',
 'pubkey': ['',
  '5']},{'time_capsule': '',
 'pubkey': ['',
  '5']},{'time_capsule': '',
 'pubkey': ['',
  '5']}]

# %%
C = [bytes_to_long(bytes.fromhex(key['time_capsule'])) for key in keys]
N = [bytes_to_long(bytes.fromhex(key['pubkey'][0])) for key in keys]
e = 5

# %%
from sympy import root
long_to_bytes(root(crt(C,N), 5))
# Out:
# b'HTB{t3h_FuTUr3_15_bR1ghT_1_H0p3_y0uR3_W34r1nG_5h4d35!}'
